# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\hp\Downloads\MER_T07_02A-2020-02-03.csv")
df
# Out:
#           MSN  YYYYMM       Value  Column_Order  \
# 0     CLETPUS  194913   135451.32             1
# 1     CLETPUS  195013  154519.994             1
# 2     CLETPUS  195113  185203.657             1
# 3     CLETPUS  195213  195436.666             1
# 4     CLETPUS  195313  218846.325             1
# ...       ...     ...         ...           ...
# 8211  ELETPUS  201906  351342.905            13
# 8212  ELETPUS  201907  411583.828            13
# 8213  ELETPUS  201908  401363.186            13
# 8214  ELETPUS  201909  359300.603            13
# 8215  ELETPUS  201910  321921.812            13
#
#                                             Description                   Unit
# 0     Electricity Net Generation From Coal, All Sectors  Million Kilowatthours
# 1     Electricity Net Generation From Coal, All Sectors  Million Kilowatthours
# 2     Electricity Net Generation From Coal, All Sectors  Million Kilowatthours
# ...

# %%
df.describe()
# Out:
#               YYYYMM  Column_Order
# count    8216.000000   8216.000000
# mean   199461.476266      7.000000
# std      1492.616509      3.741885
# min    194913.000000      1.000000
# 25%    198304.750000      4.000000
# 50%    199506.500000      7.000000
# 75%    200708.250000     10.000000
# max    201910.000000     13.000000

# %%
df.tail()
# Out:
#           MSN  YYYYMM       Value  Column_Order  \
# 8211  ELETPUS  201906  351342.905            13
# 8212  ELETPUS  201907  411583.828            13
# 8213  ELETPUS  201908  401363.186            13
# 8214  ELETPUS  201909  359300.603            13
# 8215  ELETPUS  201910  321921.812            13
#
#                                             Description                   Unit
# 8211  Electricity Net Generation Total (including fr...  Million Kilowatthours
# 8212  Electricity Net Generation Total (including fr...  Million Kilowatthours
# 8213  Electricity Net Generation Total (including fr...  Million Kilowatthours
# 8214  Electricity Net Generation Total (including fr...  Million Kilowatthours
# 8215  Electricity Net Generation Total (including fr...  Million Kilowatthours

# %%
df2=pd.read_excel(r"C:\Users\hp\Desktop\SampleTemperature Sheet.xlsx")
df2.describe()
# Out:
#        Temprature Sheet Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# count                 5         17          18          17          18
# unique                5          5          10          10          10
# top               Month     Week 1          10          18           6
# freq                  1          4           4           4           4
#
#         Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# count           17          18          17          18          17
# unique           8          11          10           9           9
# top             21           6          19           8          20
# freq             5           4           4           5           4
#
#         Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14  \
# count            18           17           18           17           18
# unique           11           12           11           14           11
# ...

# %%
df2.tail()
# Out:
#    Temprature Sheet Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 14              NaN     Week 4          7         22          2         21
# 15         February     Week 1         10         20          7         22
# 16              NaN     Week 2         10         18         10         22
# 17              NaN     Week 3          8         18          8         18
# 18              NaN     Week 4          9         20          7         21
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 14          6         22          6         21           5          19
# 15        -10         19          8         21           9          18
# 16         11         19          9         20           9          18
# 17         10         19         10         20          11          18
# 18          8         18          8         19           9          20
#
#    Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15
# ...

# %%
df2.head()
# Out:
#   Temprature Sheet Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0              NaN        NaN        NaN        NaN        NaN        NaN
# 1            Month       Week     Monday        NaN    Tuesday        NaN
# 2         November        NaN   Min Temp   Max Temp   Min Temp   Max Temp
# 3              NaN     Week 1          8         27         13         23
# 4              NaN     Week 2         14         26         13         21
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0        NaN        NaN        NaN        NaN         NaN         NaN
# 1  Wednesday        NaN   Thursday        NaN      Friday         NaN
# 2   Min Temp   Max Temp   Min Temp   Max Temp    Min Temp    Max Temp
# 3          7         22          8         23           7          25
# 4          6         20        -13         32          14          23
#
#   Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15
# ...

# %%
import pandas as pd

# %%
df3=pd.read_csv(r"C:\Users\hp\Downloads\police.csv")

# %%
df3
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0      2005-01-02     01:55          NaN             M          1985.0
# 1      2005-01-18     08:15          NaN             M          1965.0
# 2      2005-01-23     23:15          NaN             M          1972.0
# 3      2005-02-20     17:15          NaN             M          1986.0
# 4      2005-03-14     10:00          NaN             F          1984.0
# ...           ...       ...          ...           ...             ...
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# ...

# %%
df3.head(50)
# Out:
#      stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0   2005-01-02     01:55          NaN             M          1985.0
# 1   2005-01-18     08:15          NaN             M          1965.0
# 2   2005-01-23     23:15          NaN             M          1972.0
# 3   2005-02-20     17:15          NaN             M          1986.0
# 4   2005-03-14     10:00          NaN             F          1984.0
# 5   2005-03-23     09:45          NaN             M          1982.0
# 6   2005-04-01     17:30          NaN             M          1969.0
# 7   2005-06-06     13:20          NaN             F          1986.0
# 8   2005-07-13     10:15          NaN             M          1970.0
# 9   2005-07-13     15:45          NaN             M          1970.0
# 10  2005-07-13     16:20          NaN             M          1979.0
# 11  2005-07-13     19:00          NaN             F          1966.0
# 12  2005-07-14     19:55          NaN             M          1979.0
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91741 entries, 0 to 91740
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           91741 non-null  object
#  1   stop_time           91741 non-null  object
#  2   county_name         0 non-null      float64
#  3   driver_gender       86406 non-null  object
#  4   driver_age_raw      86414 non-null  float64
#  5   driver_age          86120 non-null  float64
#  6   driver_race         86408 non-null  object
#  7   violation_raw       86408 non-null  object
#  8   violation           86408 non-null  object
#  9   search_conducted    91741 non-null  bool
#  10  search_type         3196 non-null   object
#  11  stop_outcome        86408 non-null  object
#  12  is_arrested         86408 non-null  object
#  13  stop_duration       86408 non-null  object
#  14  drugs_related_stop  91741 non-null  bool
# ...

# %%
df3.shape
# Out:
# (91741, 15)

# %%
tem_df3=df3.append(df3)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7832\3638936199.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tem_df3=df3.append(df3)

# %%
tem_df3.shape
# Out:
# (183482, 15)

# %%
tem_df3.loc[1]
# Out:
#     stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 1  2005-01-18     08:15          NaN             M          1965.0
# 1  2005-01-18     08:15          NaN             M          1965.0
#
#    driver_age driver_race violation_raw violation  search_conducted  \
# 1        40.0       White      Speeding  Speeding             False
# 1        40.0       White      Speeding  Speeding             False
#
#   search_type stop_outcome is_arrested stop_duration  drugs_related_stop
# 1         NaN     Citation       False      0-15 Min               False
# 1         NaN     Citation       False      0-15 Min               False

# %%
tem_df3.drop_duplicates()
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0      2005-01-02     01:55          NaN             M          1985.0
# 1      2005-01-18     08:15          NaN             M          1965.0
# 2      2005-01-23     23:15          NaN             M          1972.0
# 3      2005-02-20     17:15          NaN             M          1986.0
# 4      2005-03-14     10:00          NaN             F          1984.0
# ...           ...       ...          ...           ...             ...
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# ...

# %%
te

# %% [markdown]
# tem_df3.drop_duplicates(self,subst=clomn,keep=first/last/false,inplace=true)

# %%
tem_df3.drop_duplicates(inplace=True)

# %%
dup_rem_df3=tem_df3.drop_duplicates(keep='first')

# %%
dup_rem_df3.loc[1]
# Out:
# stop_date             2005-01-18
# stop_time                  08:15
# county_name                  NaN
# driver_gender                  M
# driver_age_raw            1965.0
# driver_age                  40.0
# driver_race                White
# violation_raw           Speeding
# violation               Speeding
# search_conducted           False
# search_type                  NaN
# stop_outcome            Citation
# is_arrested                False
# stop_duration           0-15 Min
# drugs_related_stop         False
# Name: 1, dtype: object

# %%
dup_rem_df3=tem_df3.drop_duplicates(keep=False)

# %%
dup_rem_df3
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0      2005-01-02     01:55          NaN             M          1985.0
# 1      2005-01-18     08:15          NaN             M          1965.0
# 2      2005-01-23     23:15          NaN             M          1972.0
# 3      2005-02-20     17:15          NaN             M          1986.0
# 4      2005-03-14     10:00          NaN             F          1984.0
# ...           ...       ...          ...           ...             ...
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# ...

# %%
tem_df3
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0      2005-01-02     01:55          NaN             M          1985.0
# 1      2005-01-18     08:15          NaN             M          1965.0
# 2      2005-01-23     23:15          NaN             M          1972.0
# 3      2005-02-20     17:15          NaN             M          1986.0
# 4      2005-03-14     10:00          NaN             F          1984.0
# ...           ...       ...          ...           ...             ...
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# ...

# %%
tem_df3.mean()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7832\1801460394.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   tem_df3.mean()
# county_name                   NaN
# driver_age_raw        1970.497406
# driver_age              34.012755
# search_conducted         0.034921
# is_arrested              0.033608
# drugs_related_stop       0.008919
# dtype: float64

# %%
tem_df3.std()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7832\975399738.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   tem_df3.std()
# county_name                  NaN
# driver_age_raw        110.882213
# driver_age             12.737448
# search_conducted        0.183582
# is_arrested             0.180220
# drugs_related_stop      0.094021
# dtype: float64

# %%
import pandas as pd

# %%
d={'a':[1,1,3,4,4,5],'b':[1,1,3,4,5,6]}

# %%
df=pd.DataFrame(d)

# %%
df
# Out:
#    a  b
# 0  1  2
# 1  2  3
# 2  3  4
# 3  4  1
# 4  5  4

# %%
df.drop_duplicates(subset=['a'])
# Out:
#    a  b
# 0  1  2
# 1  2  3
# 2  3  4
# 3  4  1
# 4  5  4
