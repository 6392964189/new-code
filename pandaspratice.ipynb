# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\hp\Downloads\IMDB-Movie-Data.csv")

# %%
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
df.sample(n=10)
# Out:
#      Rank                     Title                       Genre  \
# 237   238  The Disappointments Room       Drama,Horror,Thriller
# 817   818                 127 Hours   Adventure,Biography,Drama
# 192   193                 Spotlight         Crime,Drama,History
# 981   982                     Annie         Comedy,Drama,Family
# 665   666             Anna Karenina               Drama,Romance
# 312   313              The Babadook                Drama,Horror
# 814   815         Fantastic Mr. Fox  Animation,Adventure,Comedy
# 481   482                 The Giver        Drama,Romance,Sci-Fi
# 727   728           The Illusionist       Drama,Mystery,Romance
# 834   835              The Dictator                      Comedy
#
#                                            Description       Director  \
# 237  A mother and her young son release unimaginabl...    D.J. Caruso
# 817  An adventurous mountain climber becomes trappe...    Danny Boyle
# ...

# %%
df.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
df.nunique()
# Out:
# Rank                  1000
# Title                  999
# Genre                  207
# Description           1000
# Director               644
# Actors                 996
# Year                    11
# Runtime (Minutes)       94
# Rating                  55
# Votes                  997
# Revenue (Millions)     814
# Metascore               84
# dtype: int64

# %%
df.isna().any()
# Out:
# Rank                  False
# Title                 False
# Genre                 False
# Description           False
# Director              False
# Actors                False
# Year                  False
# Runtime (Minutes)     False
# Rating                False
# Votes                 False
# Revenue (Millions)     True
# Metascore              True
# dtype: bool

# %%
df.isnull()
# Out:
#       Rank  Title  Genre  Description  Director  Actors   Year  \
# 0    False  False  False        False     False   False  False
# 1    False  False  False        False     False   False  False
# 2    False  False  False        False     False   False  False
# 3    False  False  False        False     False   False  False
# 4    False  False  False        False     False   False  False
# ..     ...    ...    ...          ...       ...     ...    ...
# 995  False  False  False        False     False   False  False
# 996  False  False  False        False     False   False  False
# 997  False  False  False        False     False   False  False
# 998  False  False  False        False     False   False  False
# 999  False  False  False        False     False   False  False
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 0                False   False  False               False      False
# 1                False   False  False               False      False
# ...

# %%
df.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df.nsmallest(10,'Votes')
# Out:
#      Rank                     Title                    Genre  \
# 478   479            Paint It Black                    Drama
# 293   294             The Exception                    Drama
# 393   394             Whisky Galore           Comedy,Romance
# 337   338                 Tracktown              Drama,Sport
# 416   417  The Headhunter's Calling                    Drama
# 647   648                  Tall Men  Fantasy,Horror,Thriller
# 250   251              Bonjour Anne     Comedy,Drama,Romance
# 538   539               True Crimes     Crime,Drama,Thriller
# 890   891                The Intent              Crime,Drama
# 439   440     Folk Hero & Funny Guy                   Comedy
#
#                                            Description            Director  \
# 478  A young woman attempts to deal with the death ...       Amber Tamblyn
# 293  A German soldier tries to determine if the Dut...       David Leveaux
# ...

# %%
df.loc[1:6, ['Director','Actors']]
# Out:
#                Director                                             Actors
# 1          Ridley Scott  Noomi Rapace, Logan Marshall-Green, Michael Fa...
# 2    M. Night Shyamalan  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# 3  Christophe Lourdelet  Matthew McConaughey,Reese Witherspoon, Seth Ma...
# 4            David Ayer  Will Smith, Jared Leto, Margot Robbie, Viola D...
# 5           Yimou Zhang      Matt Damon, Tian Jing, Willem Dafoe, Andy Lau
# 6       Damien Chazelle  Ryan Gosling, Emma Stone, Rosemarie DeWitt, J....

# %%
df.sort_values(by= 'Year',ascending=False)
# Out:
#      Rank                               Title                    Genre  \
# 999  1000                          Nine Lives    Comedy,Family,Fantasy
# 161   162                           Free Fire      Action,Comedy,Crime
# 647   648                            Tall Men  Fantasy,Horror,Thriller
# 234   235          The Huntsman: Winter's War   Action,Adventure,Drama
# 653   654  Popstar: Never Stop Never Stopping             Comedy,Music
# ..    ...                                 ...                      ...
# 715   716                          Happy Feet  Animation,Comedy,Family
# 727   728                     The Illusionist    Drama,Mystery,Romance
# 965   966                       Inland Empire   Drama,Mystery,Thriller
# 559   560                           Idiocracy  Adventure,Comedy,Sci-Fi
# 230   231                     Pan's Labyrinth        Drama,Fantasy,War
#
#                                            Description               Director  \
# ...

# %%
df['Actors']
# Out:
# 0      Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# 1      Noomi Rapace, Logan Marshall-Green, Michael Fa...
# 2      James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# 3      Matthew McConaughey,Reese Witherspoon, Seth Ma...
# 4      Will Smith, Jared Leto, Margot Robbie, Viola D...
#                              ...
# 995    Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...
# 996    Lauren German, Heather Matarazzo, Bijou Philli...
# 997    Robert Hoffman, Briana Evigan, Cassie Ventura,...
# 998    Adam Pally, T.J. Miller, Thomas Middleditch,Sh...
# 999    Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...
# Name: Actors, Length: 1000, dtype: object

# %%
type(df['Actors'])
# Out:
# pandas.core.series.Series

# %%
df[df.Rating>=8]
# Out:
#      Rank                     Title                       Genre  \
# 0       1   Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 6       7                La La Land          Comedy,Drama,Music
# 16     17             Hacksaw Ridge     Biography,Drama,History
# 18     19                      Lion             Biography,Drama
# 19     20                   Arrival        Drama,Mystery,Sci-Fi
# ..    ...                       ...                         ...
# 742   743    El secreto de sus ojos       Drama,Mystery,Romance
# 765   766                        PK        Comedy,Drama,Romance
# 772   773  How to Train Your Dragon  Animation,Action,Adventure
# 861   862            Koe no katachi     Animation,Drama,Romance
# 991   992          Taare Zameen Par          Drama,Family,Music
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
[df.Rating==df['Rating'].max()]
# Out:
# [0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  995    False
#  996    False
#  997    False
#  998    False
#  999    False
#  Name: Rating, Length: 1000, dtype: bool]

# %%
import pandas as pd

# %%
ds=pd.Series([2,4,7,9])
ds
# Out:
# 0    2
# 1    4
# 2    7
# 3    9
# dtype: int64

# %%
df_data=pd.DataFrame({'w':[78,98,88,90,None], 'x':[78,90,89,96,None]})
sr_data=pd.Series([68,89,90,98,None])
df_data
sr_data
# Out:
# 0    68.0
# 1    89.0
# 2    90.0
# 3    98.0
# 4     NaN
# dtype: float64

# %%
sum
# Out:
# <function sum(iterable, /, start=0)>

# %%
import pandas as pd

# %%
data = {'Name':['Arpit','Vipul,'Avinash','Prashant','Shobhit','Namrata'],
      'age':[27,28,36,38,25,29],
      'salary':[40000,50000,120000,100000,80000,70000],
      'designation':['engineer','networking','owner','director','data scientist','hr']}
# Out:
#   Cell In[67], line 1
#     data = {'Name':['Arpit','Vipul,'Avinash','Prashant','Shobhit','Namrata'],
#                                                                           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
data = {'name': ['arpit','vipul','avinash','prashant','shobhit','namrata']
         'age': [ 


            
         ]
